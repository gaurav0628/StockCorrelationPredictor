# %% [markdown]
# To run ARIMA-LSTM/SARIMAX-LSTM prediction model, latest stock data for S&P500 firms is required. Code in this
# notebook is used to scrape wikipedia to extract list of S&P500 firms using the Beautiful Soup library. Then stock
# data for each ticker will be scraped using a AlphaVantage API, which is a free service for getting stock related
# data. Alpha Vantage requires a key which is given upon creation of a free account. This key can service 5 aPI
# request/min (one of the reasons why this module works slowly as I have introduced a delay of 1 min/5 reqs). I used
# a simple selenium and javascript script to automate the process of creating keys and generated 10 free keys. These
# keys are used in the following modules. This module can be used to pull 'fresh' stock data from the market
# everytime during portfolio creation. Data is stored in csv format for individually for each stock, serving as
# input for data pre processing module.

# %% [markdown]
# Cell 1 contains imports which will be required to run this module.

# %%
#Cell 1 - Imports 

import bs4 as bs
import os
import pandas as pd
import requests
from alpha_vantage.timeseries import TimeSeries
import os
import time as tm
import random

# %% [markdown]
# Code in cell 2 will be used to extract S&P500 list and their tickers from wikipedia.
# This can be achieved with the help of Beautiful Soup library.

# %%
#Cell 2 - Tickers

#Pull the data from wiki link of S&P500 firms.
resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs.BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})
tickers = []
companies = []
sectors = []
sub_industries = []

#append required columns and save the data in csv format.
for row in table.findAll('tr')[1:]:
    ticker = row.findAll('td')[0].text
    tickers.append(ticker.rstrip())
    company = row.findAll('td')[1].text
    companies.append(company.rstrip())
    sector = row.findAll('td')[3].text
    sectors.append(sector.rstrip())
    sub_industry = row.findAll('td')[4].text
    sub_industries.append(sub_industry.rstrip())

SP500List = pd.DataFrame(
{'ticker' : tickers,
 'company': companies,
 'GICS_sector': sub_industries,
 'GICS_sub_industry': sectors
})
SP500List.to_csv('/Users/gauravthapliyal/Desktop/Project Data/SP500_list.csv')
print(SP500List)
# Out:
#     ticker                 company                         GICS_sector  \
# 0      MMM              3M Company            Industrial Conglomerates
# 1      ABT     Abbott Laboratories               Health Care Equipment
# 2     ABBV             AbbVie Inc.                     Pharmaceuticals
# 3     ABMD             ABIOMED Inc               Health Care Equipment
# 4      ACN           Accenture plc      IT Consulting & Other Services
# ..     ...                     ...                                 ...
# 500    YUM         Yum! Brands Inc                         Restaurants
# 501   ZBRA      Zebra Technologies  Electronic Equipment & Instruments
# 502    ZBH  Zimmer Biomet Holdings               Health Care Equipment
# 503   ZION           Zions Bancorp                      Regional Banks
# 504    ZTS                  Zoetis                     Pharmaceuticals
#
#           GICS_sub_industry
# 0               Industrials
# 1               Health Care
# 2               Health Care
# 3               Health Care
# 4    Information Technology
# ..                      ...
# 500  Consumer Discretionary
# 501  Information Technology
# 502             Health Care
# 503              Financials
# 504             Health Care
#
# [505 rows x 4 columns]

# %% [markdown]
# Code in this cell will be used to stock data from 2000 to 2020 (20 years) using tickers extrcted from S&P500 list.
# Alpha Vantage API is used for this. A explicit delay of 1 min is kept as only 5 API req/min are supported by Alpha
# Vantage key. Keys are stored in 'Alpha Vantage Keys.txt' file which is mandatory for extracting data from the API.
# reset_key function resets key as soon as 5 requests are performed on a key and selects a new key from the pool of
# 10 available keys. Track of used keys is kept in a keys_list queue. Once the queue is full, its reset after a wait
# of 1 min (due to API restritcion). Each stock is stored as individual csv

# %%
#Cell 3 - Stock Data per Ticker

#function definition for reset_key which resets the key value.
def reset_key(i):
    if i > 4:
        lines = open('/Users/gauravthapliyal/Desktop/Project Data/Alpha Vantage Keys.txt').read().splitlines()
        while True:
            if len(keys_list) > 4:
                print("Sleep Time of 1 min")
                tm.sleep(60)
                keys_list.clear()
                i = 0
            API_KEY = random.choice(lines)
            if(API_KEY not in keys_list):
                keys_list.append(API_KEY)
                print("API Key Changed. Current Key: "+API_KEY)
                i = 0
                break

#extract key from txt file. Access API per ticker, extract and store data in csv.
lines = open('/Users/gauravthapliyal/Desktop/Project Data/Alpha Vantage Keys.txt').read().splitlines()
API_KEY = random.choice(lines)
print(API_KEY)
tickers = list(SP500List.ticker)
print(tickers)
i = 0
keys_list = []
keys_list.append(API_KEY)

path = '/Users/gauravthapliyal/Desktop/Project Data/ticker_stock_data'
for file in os.listdir(path) :
    os.remove(path+'/'+file)
for item in tickers:
    try:
        time = TimeSeries(key = API_KEY, output_format = 'pandas')
        i += 1
        reset_key(i)
        data_adj = time.get_daily_adjusted(symbol = item, outputsize = 'full')
        i += 1
        reset_key(i)
        df = pd.DataFrame(data_adj[0])

        data_dir = "/Users/gauravthapliyal/Desktop/Project Data/ticker_stock_data/"+item+".csv"
        df.to_csv(data_dir)
        
        #Reloads data
        if os.path.getsize(data_dir) < 250000 :
            print(item+' file size '+str(os.path.getsize(data_dir))+' bytes : reloading data...')
            data_adj = time.get_daily_adjusted(symbol = item, outputsize = 'full')
            reset_key(i)
            i += 1
            df = pd.DataFrame(data_adj[0])
            df.to_csv(data_dir)
    except ValueError:
        print("Unable to get data for ticker: "+ item)
        continue
# Out:
# 5G2IU7O4KWJBA4T4
# ['MMM', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BKR', 'BLL', 'BAC', 'BK', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BF.B', 'CHRW', 'COG', 'CDNS', 'CPB', 'COF', 'CPRI', 'CAH', 'KMX', 'CCL', 'CARR', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'CTVA', 'COST', 'COTY', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'FANG', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DOW', 'DTE', 'DUK', 'DRE', 'DD', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EOG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'EVRG', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FRC', 'FISV', 'FLT', 'FLIR', 'FLS', 'FMC', 'F', 'FTNT', 'FTV', 'FBHS', 'FOXA', 'FOX', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'GWW', 'HRB', 'HAL', 'HBI', 'HOG', 'HIG', 'HAS', 'HCA', 'PEAK', 'HP', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HFC', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IEX', 'IDXX', 'INFO', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IBM', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IPGP', 'IQV', 'IRM', 'JKHY', 'J', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LEG', 'LDOS', 'LEN', 'LLY', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MKC', 'MXIM', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'MYL', 'NDAQ', 'NOV', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NLOK', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'ORLY', 'OXY', 'ODFL', 'OMC', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'FTI', 'TFX', 'TXN', 'TXT', 'TMO', 'TIF', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TFC', 'TWTR', 'TSN', 'UDR', 'ULTA', 'USB', 'UAA', 'UA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAC', 'V', 'VNO', 'VMC', 'WRB', 'WAB', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# ABBV file size 112399 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# ALLE file size 97718 bytes : reloading data...
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# GOOG file size 99799 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# AMCR file size 12865 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# AAL file size 218583 bytes : reloading data...
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# AWK file size 182610 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# AMP file size 228360 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# APTV file size 128467 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# ANET file size 89719 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# AIZ file size 245786 bytes : reloading data...
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# BKR file size 42847 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# AVGO file size 169813 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# BR file size 199191 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Unable to get data for ticker: BF.B
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# CPRI file size 123056 bytes : reloading data...
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# CARR file size 1480 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# CBOE file size 151036 bytes : reloading data...
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# CBRE file size 31058 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# CDW file size 104455 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# CE file size 233198 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# CF file size 227751 bytes : reloading data...
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# CHTR file size 158687 bytes : reloading data...
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# CMG file size 220064 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# CFG file size 85324 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# CXO file size 199856 bytes : reloading data...
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# CTVA file size 13988 bytes : reloading data...
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# COTY file size 103961 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# DAL file size 195705 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# FANG file size 116690 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# DLR file size 237685 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# DFS file size 195593 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# DISCA file size 222324 bytes : reloading data...
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# DISCK file size 171078 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# DG file size 161256 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# DOW file size 16765 bytes : reloading data...
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# DD file size 13719 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# DXC file size 49448 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# EVRG file size 28878 bytes : reloading data...
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# EXPE file size 230386 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# EXR file size 235191 bytes : reloading data...
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# FB file size 124744 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# FRC file size 142549 bytes : reloading data...
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# FLT file size 144185 bytes : reloading data...
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# FTNT file size 153921 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: EU981683CQ3RMO82
# FTV file size 57959 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# FBHS file size 130418 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# FOXA file size 17188 bytes : reloading data...
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# FOX file size 17032 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# GM file size 145185 bytes : reloading data...
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# HBI file size 205243 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# HCA file size 141520 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# HPE file size 69342 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# HLT file size 97525 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# HII file size 143872 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# INFO file size 88624 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# IR file size 43254 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# ICE file size 226721 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# IPGP file size 200430 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: EU981683CQ3RMO82
# IQV file size 104563 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# KEYS file size 80897 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# KMI file size 141443 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# KHC file size 73562 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# LW file size 52136 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# LVS file size 233680 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# LDOS file size 205346 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# LIN file size 24467 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# LYV file size 205568 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# LKQ file size 242276 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# LYB file size 153545 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# MPC file size 135160 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# MKTX file size 234697 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# MA file size 222281 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# MSCI file size 190564 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# NWSA file size 104803 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# NWS file size 102584 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# NLSN file size 140661 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# NCLH file size 106702 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# NRG file size 248650 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# ...
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# PM file size 186363 bytes : reloading data...
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# PSX file size 123801 bytes : reloading data...
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# QRVO file size 78369 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# CRM file size 240537 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# NOW file size 118408 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# SYF file size 87638 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# TMUS file size 192397 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# TEL file size 196013 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# TDG file size 221131 bytes : reloading data...
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# TWTR file size 96648 bytes : reloading data...
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# ULTA file size 191160 bytes : reloading data...
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# UAA file size 213759 bytes : reloading data...
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# UA file size 59739 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# UAL file size 209318 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# Sleep Time of 1 min
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# VRSK file size 161476 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# VIAC file size 217337 bytes : reloading data...
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# V file size 191368 bytes : reloading data...
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: OW3QQB8OOTAFFSN5
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# WU file size 207245 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# WRK file size 73721 bytes : reloading data...
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# Sleep Time of 1 min
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# WLTW file size 70253 bytes : reloading data...
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# Sleep Time of 1 min
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: EU981683CQ3RMO82
# Sleep Time of 1 min
# API Key Changed. Current Key: EU981683CQ3RMO82
# XYL file size 129059 bytes : reloading data...
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# API Key Changed. Current Key: O6A4SAOHY74UMKC6
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# Sleep Time of 1 min
# API Key Changed. Current Key: DMF2DOGRKQ46ROD2
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
# API Key Changed. Current Key: 0WQ1JLQHV1L5GVH0
# API Key Changed. Current Key: FJ7UGH182N6LDVSC
# API Key Changed. Current Key: 5G2IU7O4KWJBA4T4
# Sleep Time of 1 min
# API Key Changed. Current Key: 3H2MHRQEN5H8VL63
# API Key Changed. Current Key: KTB0QU02FXW7T76E
# ZTS file size 111760 bytes : reloading data...
# API Key Changed. Current Key: 714R4KO6HVWV3QJI
